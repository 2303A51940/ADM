# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51940/ADM/blob/main/employee-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/sample_data/employee_data.csv")

# %%
print("Data Before Preprocessing")
print(df)
# Out:
# Data Before Preprocessing
#     Employee_ID   Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.0  108953.0               9.0                   36
# 1          1002  36.0   82995.0               8.0                   59
# 2          1003  29.0   70757.0               2.0                   30
# 3          1004  42.0   39692.0               1.0                   30
# 4          1005  40.0   75758.0               7.0                   54
# 5          1006  44.0  102409.0               7.0                   56
# 6          1007  32.0       NaN               NaN                   59
# 7          1008  32.0   95697.0               5.0                   54
# 8          1009  45.0   67065.0               3.0                   49
# 9          1010  57.0       NaN               8.0                   42
# 10         1011  45.0   41534.0               6.0                   38
# 11         1012   NaN   70397.0               NaN                   32
# ...

# %%
df.isna()
# Out:
#     Employee_ID    Age  Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0         False  False   False             False                False
# 1         False  False   False             False                False
# 2         False  False   False             False                False
# 3         False  False   False             False                False
# 4         False  False   False             False                False
# 5         False  False   False             False                False
# 6         False  False    True              True                False
# 7         False  False   False             False                False
# 8         False  False   False             False                False
# 9         False  False    True             False                False
# 10        False  False   False             False                False
# 11        False   True   False              True                False
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame loaded from 'Social_Media_Engagement.csv'

# Group numerical and categorical columns
numerical_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Impute missing values
for col in numerical_cols:
    if df[col].isnull().any():  # Check if column has missing values
        if len(df[col].unique()) > 10:  # Use mean/median for continuous data
            # Check skewness to determine imputation method
            if df[col].skew() > 1:  # Highly skewed
                df[col].fillna(df[col].median(), inplace=True)  # Impute median for skewed data
            else:
                df[col].fillna(df[col].mean(), inplace=True)  # Impute mean for relatively normal data
        else:
            df[col].fillna(df[col].mode()[0], inplace=True)  # Mode for discrete data

# Impute missing values for categorical columns
for col in categorical_cols:
    if df[col].isnull().any():
        df[col].fillna(df[col].mode()[0], inplace=True)  # Mode for categorical data

print(df)
# Out:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0              9.00                   36
# 1          1002  36.000000   82995.0              8.00                   59
# 2          1003  29.000000   70757.0              2.00                   30
# 3          1004  42.000000   39692.0              1.00                   30
# 4          1005  40.000000   75758.0              7.00                   54
# 5          1006  44.000000  102409.0              7.00                   56
# 6          1007  32.000000   72349.2              5.55                   59
# 7          1008  32.000000   95697.0              5.00                   54
# 8          1009  45.000000   67065.0              3.00                   49
# 9          1010  57.000000   72349.2              8.00                   42
# 10         1011  45.000000   41534.0              6.00                   38
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df' is your DataFrame and contains 'Age' and 'Salary' columns

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit and transform the selected columns
df[['Age', 'Salary']] = scaler.fit_transform(df[['Age', 'Salary']])

print(df)
# Out:
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  0.750000  0.877708              9.00                   36
# 1          1002  0.361111  0.585375              8.00                   59
# 2          1003  0.166667  0.447554              2.00                   30
# 3          1004  0.527778  0.097707              1.00                   30
# 4          1005  0.472222  0.503874              7.00                   54
# 5          1006  0.583333  0.804011              7.00                   56
# 6          1007  0.250000  0.465485              5.55                   59
# 7          1008  0.250000  0.728422              5.00                   54
# 8          1009  0.611111  0.405975              3.00                   49
# 9          1010  0.944444  0.465485              8.00                   42
# 10         1011  0.611111  0.118451              6.00                   38
# ...

# %%
def min_max_normalize(series):
    return (series - series.min()) / (series.max() - series.min())

    df['Job_Satisfaction_Norm'] = min_max_normalize(df['Job_Satisfaction'])
    df['Work_Hours_Per_Week_Norm'] = min_max_normalize(df['Work_Hours_Per_Week'])

    print(df[['Job_Satisfaction', 'Job_Satisfaction_Norm',
    'Work_Hours_Per_Week', 'Work_Hours_Per_Week_Norm']].head())

# %%
print("Data After Preprocessing")
print(df)
# Out:
# Data After Preprocessing
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  0.750000  0.877708              9.00                   36
# 1          1002  0.361111  0.585375              8.00                   59
# 2          1003  0.166667  0.447554              2.00                   30
# 3          1004  0.527778  0.097707              1.00                   30
# 4          1005  0.472222  0.503874              7.00                   54
# 5          1006  0.583333  0.804011              7.00                   56
# 6          1007  0.250000  0.465485              5.55                   59
# 7          1008  0.250000  0.728422              5.00                   54
# 8          1009  0.611111  0.405975              3.00                   49
# 9          1010  0.944444  0.465485              8.00                   42
# 10         1011  0.611111  0.118451              6.00                   38
# ...
